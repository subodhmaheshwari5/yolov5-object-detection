# %%
# Clone YOLOv5
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# Go to YOLOv5 folder
import os
os.chdir('yolov5')

# %%
# Install required packages
# !pip install -r requirements.txt

# %%
# Detect objects in image
# !python detect.py --source data/images/bus.jpg --weights yolov5s.pt --conf 0.25
# Out:
# detect: weights=['yolov5s.pt'], source=data/images/bus.jpg, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-462-g404a1621 Python-3.13.5 torch-2.10.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 C:\Users\subod\yolov5\yolov5\data\images\bus.jpg: 640x480 4 persons, 1 bus, 98.4ms
# Speed: 0.6ms pre-process, 98.4ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\exp10

# %%
# Show detected result
from IPython.display import Image, display
import glob

results = sorted(glob.glob('runs/detect/exp*/*.jpg'))
display(Image(filename=results[-1], width=300))

# %%
# Run detection on your image
# !python detect.py --source "C:\Users\subod\OneDrive\Desktop\WhatsApp Image 2026-03-18 at 1.07.08 AM.jpeg" --weights yolov5s.pt --conf 0.25

# Automatically find the LATEST result 
from IPython.display import Image, display
import glob

results = sorted(glob.glob('runs/detect/exp*/*WhatsApp Image 2026-03-18 at 1.07.08 AM.jpeg'))
print("Found:", results[-1])  # shows which file it picked
display(Image(filename=results[-1], width=1200))
# Out:
# Found: runs/detect\exp6\WhatsApp Image 2026-03-18 at 1.07.08 AM.jpeg
# detect: weights=['yolov5s.pt'], source=C:\Users\subod\OneDrive\Desktop\WhatsApp Image 2026-03-18 at 1.07.08 AM.jpeg, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-462-g404a1621 Python-3.13.5 torch-2.10.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 C:\Users\subod\OneDrive\Desktop\WhatsApp Image 2026-03-18 at 1.07.08 AM.jpeg: 256x640 6 persons, 16 cars, 6 buss, 68.8ms
# ...

# %%
# source=0 means your default webcam (like a live feed)
# Press Q to stop the webcam window
# Note => This opens a separate window, not inside Jupyter

# !python detect.py --source 0 --weights yolov5s.pt --conf 0.25
